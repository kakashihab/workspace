# %%
import pandas as pd

# %%
from matplotlib import pyplot

# %%
x = [1,2,3,4,5]
y = [10,5,8,16,23]
z = [1,4,3,6,5]
pyplot.plot(x,y)
pyplot.plot(x,z)
pyplot.legend(["y values", "z values"])
pyplot.xlabel("Sales")
pyplot.ylabel("Month")
pyplot.title("My sales graph")
pyplot.show()

# %%
df = pd.read_csv("random_numbers.csv")

# %%
df.shape
# Out:
# (1000, 4)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        A    B    C    D
# 0     80   56  114   76
# 1     67   56  102   81
# 2    107  107  129   86
# 3     75   54  150   86
# 4     51  133   76   88
# ..   ...  ...  ...  ...
# 995  128  121   67   64
# 996   87  113  116   52
# 997  122  134   95  131
# 998  138  146   54  133
# 999  147   66  135   81
#
# [1000 rows x 4 columns]>

# %%
df.nunique()
# Out:
# A    101
# B    101
# C    101
# D    101
# dtype: int64

# %%
df.drop(["A"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.drop(["A"])
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5249 def drop(  # type: ignore[override]
#    5250     self,
#    (...)
#    5257     errors: IgnoreRaise = "raise",
#    5258 ) -> DataFrame | None:
#    5259     """
#    5260     Drop specified labels from rows or columns.
#    5261
#    (...)
#    5394             weight  1.0     0.8
#    5395     """
# -> 5396     return super().drop(
#    5397         labels=labels,
#    5398         axis=axis,
#    5399         index=index,
#    5400         columns=columns,
#    5401         level=level,
#    5402         inplace=inplace,
#    5403         errors=errors,
#    5404     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:6977, in Index.drop(self, labels, errors)
#    6975 if mask.any():
#    6976     if errors != "ignore":
# -> 6977         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6978     indexer = indexer[~mask]
#    6979 return self.delete(indexer)
#
# KeyError: "['A'] not found in axis"

# %%
df
# Out:
#        A    B    C    D
# 0     80   56  114   76
# 1     67   56  102   81
# 2    107  107  129   86
# 3     75   54  150   86
# 4     51  133   76   88
# ..   ...  ...  ...  ...
# 995  128  121   67   64
# 996   87  113  116   52
# 997  122  134   95  131
# 998  138  146   54  133
# 999  147   66  135   81
#
# [1000 rows x 4 columns]

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        A    B    C    D
# 0     80   56  114   76
# 1     67   56  102   81
# 2    107  107  129   86
# 3     75   54  150   86
# 4     51  133   76   88
# ..   ...  ...  ...  ...
# 995  128  121   67   64
# 996   87  113  116   52
# 997  122  134   95  131
# 998  138  146   54  133
# 999  147   66  135   81
#
# [1000 rows x 4 columns]>

# %%
df = df.drop(columns=["A"])

# %%
df
# Out:
#        B    C    D
# 0     56  114   76
# 1     56  102   81
# 2    107  129   86
# 3     54  150   86
# 4    133   76   88
# ..   ...  ...  ...
# 995  121   67   64
# 996  113  116   52
# 997  134   95  131
# 998  146   54  133
# 999   66  135   81
#
# [1000 rows x 3 columns]

# %%
df
# Out:
#        B    C    D
# 0     56  114   76
# 1     56  102   81
# 2    107  129   86
# 3     54  150   86
# 4    133   76   88
# ..   ...  ...  ...
# 995  121   67   64
# 996  113  116   52
# 997  134   95  131
# 998  146   54  133
# 999   66  135   81
#
# [1000 rows x 3 columns]

# %%
pyplot.plot(df["B"], df["C"])

# %%
df["rowid"] = 1

# %%
df
# Out:
#        B    C    D  rowid
# 0     56  114   76      1
# 1     56  102   81      1
# 2    107  129   86      1
# 3     54  150   86      1
# 4    133   76   88      1
# ..   ...  ...  ...    ...
# 995  121   67   64      1
# 996  113  116   52      1
# 997  134   95  131      1
# 998  146   54  133      1
# 999   66  135   81      1
#
# [1000 rows x 4 columns]

# %%
df = df.drop(columns=["rowid"])

# %%
df
# Out:
#        B    C    D
# 0     56  114   76
# 1     56  102   81
# 2    107  129   86
# 3     54  150   86
# 4    133   76   88
# ..   ...  ...  ...
# 995  121   67   64
# 996  113  116   52
# 997  134   95  131
# 998  146   54  133
# 999   66  135   81
#
# [1000 rows x 3 columns]

# %%
df["rowid"] = range(1,101)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df["rowid"] = range(1,101)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:3978, in DataFrame.__setitem__(self, key, value)
#    3975     self._setitem_array([key], value)
#    3976 else:
#    3977     # set column
# -> 3978     self._set_item(key, value)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:4172, in DataFrame._set_item(self, key, value)
#    4162 def _set_item(self, key, value) -> None:
#    4163     """
#    4164     Add series to DataFrame in specified column.
#    4165
#    (...)
#    4170     ensure homogeneity.
#    4171     """
# -> 4172     value = self._sanitize_column(value)
#    4174     if (
#    4175         key in self.columns
#    4176         and value.ndim == 1
#    4177         and not is_extension_array_dtype(value)
#    4178     ):
#    4179         # broadcast across multiple columns if necessary
#    4180         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:4912, in DataFrame._sanitize_column(self, value)
#    4909     return _reindex_for_setitem(Series(value), self.index)
#    4911 if is_list_like(value):
# -> 4912     com.require_length_match(value, self.index)
#    4913 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
#     564         "does not match length of index "
#     565         f"({len(index)})"
#     566     )
#
# ValueError: Length of values (100) does not match length of index (1000)

# %%
df = df.sort_values(["B", "C"])

# %%
df
# Out:
#        B    C    D
# 821   50   56  120
# 9     50   67   91
# 905   50   69   52
# 312   50   77   85
# 96    50   93  148
# ..   ...  ...  ...
# 841  149  139   94
# 593  150   96  115
# 261  150  103  116
# 776  150  138  121
# 469  150  142   50
#
# [1000 rows x 3 columns]

# %%
df.to_csv("outfile.csv")

# %%
df = df.drop(
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df = df.drop(rows[101,1000])
#
# NameError: name 'rows' is not defined

# %%
cr = df.corr()

# %% [raw]
# cr

# %%
cr
# Out:
#           B         C         D
# B  1.000000 -0.021538 -0.011252
# C -0.021538  1.000000  0.007895
# D -0.011252  0.007895  1.000000

# %%
import seaborn

# %%
seaborn.heatmap(cr, xticklabels=cr.columns, yticklabels=cr.columns, annot=True)
# Out:
# <AxesSubplot: >

# %%
seaborn.relplot(x="B", y="C", hue="D", data =df)

# %%
df = pd.read_csv("mcs.csv")

# %%
df
# Out:
#                     Country Name Country Code                 Indicator Name  \
# 0                          Aruba          ABW  Mobile cellular subscriptions
# 1    Africa Eastern and Southern          AFE  Mobile cellular subscriptions
# 2                    Afghanistan          AFG  Mobile cellular subscriptions
# 3     Africa Western and Central          AFW  Mobile cellular subscriptions
# 4                         Angola          AGO  Mobile cellular subscriptions
# ..                           ...          ...                            ...
# 261                       Kosovo          XKX  Mobile cellular subscriptions
# 262                  Yemen, Rep.          YEM  Mobile cellular subscriptions
# 263                 South Africa          ZAF  Mobile cellular subscriptions
# 264                       Zambia          ZMB  Mobile cellular subscriptions
# 265                     Zimbabwe          ZWE  Mobile cellular subscriptions
#
#     Indicator Code  1960  1961  1962  1963  1964  1965  ...         2012  \
# 0      IT.CEL.SETS   0.0   NaN   NaN   NaN   NaN   0.0  ...     135000.0
# 1      IT.CEL.SETS   0.0   NaN   NaN   NaN   NaN   0.0  ...  291580283.0
# 2      IT.CEL.SETS   0.0   NaN   NaN   NaN   NaN   0.0  ...   15340115.0
# 3      IT.CEL.SETS   0.0   NaN   NaN   NaN   NaN   0.0  ...  252867120.0
# 4      IT.CEL.SETS   0.0   NaN   NaN   NaN   NaN   0.0  ...   12785109.0
# ..             ...   ...   ...   ...   ...   ...   ...  ...          ...
# 261    IT.CEL.SETS   NaN   NaN   NaN   NaN   NaN   NaN  ...          NaN
# 262    IT.CEL.SETS   0.0   NaN   NaN   NaN   NaN   0.0  ...   13900000.0
# 263    IT.CEL.SETS   0.0   NaN   NaN   NaN   NaN   0.0  ...   68394000.0
# 264    IT.CEL.SETS   0.0   NaN   NaN   NaN   NaN   0.0  ...   10524676.0
# 265    IT.CEL.SETS   0.0   NaN   NaN   NaN   NaN   0.0  ...   12613935.0
#
#             2013         2014         2015         2016         2017  \
# 0       138800.0     139700.0     141000.0          NaN          NaN
# 1    327628287.0  361512328.0  403793199.0  396261205.0  406413955.0
# 2     16807156.0   18407168.0   19709038.0   21602982.0   23929713.0
# 3    290449890.0  319468155.0  348206501.0  356136490.0  358816819.0
# 4     13285198.0   14052558.0   13884532.0   13001124.0   13323952.0
# ..           ...          ...          ...          ...          ...
# 261          NaN          NaN          NaN          NaN          NaN
# 262   16844700.0   17100000.0   15021953.0   16433055.0   15357868.0
# 263   76865278.0   79280731.0   87999492.0   82412880.0   88497610.0
# 264   10395801.0   10114867.0   11557725.0   12017034.0   13438539.0
# 265   13633167.0   11798652.0   12757410.0   12878926.0   14092104.0
#
#             2018         2019         2020         2021
# 0            NaN     141000.0     141000.0          NaN
# 1    386012231.0  458769966.0  486868958.0  397596019.0
# 2     21976355.0   22580071.0   22678024.0          NaN
# 3    384382192.0  422941609.0  457048002.0  408007989.0
# 4     13288421.0   14830154.0   14645050.0   15327864.0
# ..           ...          ...          ...          ...
# 261          NaN          NaN          NaN          NaN
# 262   15297789.0   15238000.0   15178000.0          NaN
# 263   92427958.0   96972459.0   95959439.0  100328005.0
# 264   15470270.0   17220607.0   19104208.0   20247111.0
# 265   12908992.0   13195902.0   13191708.0   14257590.0
#
# [266 rows x 66 columns]
